# %% [markdown]
# ## This notebooks show that we can reduce RMSE and MAE by
# - Limiting the departure delay from -15 to 179, and
# - Assigning one category for early departure less than -15, and
# - Assigning one category for departure delays larger than 179

# %% [markdown]
# ## Importing the need packages

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, make_scorer
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np
import os

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Defining features and target(s)

# %%
features = [
    "QUARTER",
    "MONTH",
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",

    "OP_CARRIER_AIRLINE_ID",
    "TAIL_NUM",
    "OP_CARRIER_FL_NUM",

    "ORIGIN_AIRPORT_ID",
    "ORIGIN_CITY_MARKET_ID",
    "ORIGIN_STATE_FIPS",
    "ORIGIN_WAC",
    "DEST_AIRPORT_ID",
    "DEST_CITY_MARKET_ID",
    "DEST_STATE_FIPS",
    "DEST_WAC",
    
    "CRS_DEP_TIME",
    "DEP_TIME_BLK",
    "CRS_ARR_TIME",
    "ARR_TIME_BLK",
    "CRS_ELAPSED_TIME",
    "DISTANCE",
    "DISTANCE_GROUP",
]

target = "DEP_DELAY_GROUP"

# %% [markdown]
# ## Importing the training datasets

# %%
# Get the current script's directory
current_script_dir = os.getcwd()

# Move up to the parent directory
parent_dir = os.path.dirname(current_script_dir)

# Define the sibling data directory name
data_dir = os.path.join(parent_dir, 'data')

# Load the 2022 training datset
# Use os.path.join to create the full file path
training_dataset_filename = "encoded_training_dataset_2022.csv"
file_path = os.path.join(data_dir, training_dataset_filename)

# Read the CSV file into a DataFrame
dataset_df = pd.read_csv(file_path)
training_df = dataset_df[features+ [target]].copy()

# Display the DataFrame
display(training_df)
# Out:
#          QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0              1      1             1            6                  20363
# 1              1      1             1            6                  20363
# 2              1      1             1            6                  20363
# 3              1      1             1            6                  20363
# 4              1      1             1            6                  20363
# ...          ...    ...           ...          ...                    ...
# 6551768        4     12            31            6                  20452
# 6551769        4     12            31            6                  20452
# 6551770        4     12            31            6                  20452
# 6551771        4     12            31            6                  20452
# 6551772        4     12            31            6                  20452
#
#          TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0             360               4732              10135
# 1             360               5430              11433
# 2             414               4671              10397
# 3             414               5009              13487
# 4             414               5083              11423
# ...           ...                ...                ...
# 6551768      5292               5741              12953
# 6551769      6245               3607              14321
# 6551770      6245               3686              13930
# 6551771      6245               3699              11003
# 6551772      6245               3719              13930
#
#          ORIGIN_CITY_MARKET_ID  ORIGIN_STATE_FIPS  ORIGIN_WAC  \
# 0                        30135                 42          23
# 1                        31295                 26          43
# 2                        30397                 13          34
# 3                        31650                 27          63
# 4                        31423                 19          61
# ...                        ...                ...         ...
# 6551768                  31703                 36          22
# 6551769                  34321                 23          12
# 6551770                  30977                 17          41
# 6551771                  31003                 19          61
# 6551772                  30977                 17          41
#
#          DEST_AIRPORT_ID  DEST_CITY_MARKET_ID  DEST_STATE_FIPS  DEST_WAC  \
# 0                  11433                31295               26        43
# 1                  10135                30135               42        23
# 2                  14783                34783               29        64
# 3                  11423                31423               19        61
# 4                  10397                30397               13        34
# ...                  ...                  ...              ...       ...
# 6551768            11066                31066               39        44
# 6551769            13930                30977               17        41
# 6551770            14321                34321               23        12
# 6551771            13930                30977               17        41
# 6551772            11003                31003               19        61
#
#          CRS_DEP_TIME  DEP_TIME_BLK  CRS_ARR_TIME  ARR_TIME_BLK  \
# 0                1015             5          1209             7
# 1                1422             9          1548            10
# 2                2057            15          2149            16
# 3                1041             5          1153             6
# 4                1300             8          1610            11
# ...               ...           ...           ...           ...
# 6551768           830             3          1038             5
# 6551769           635             1           758             2
# 6551770          1800            13          2129            16
# 6551771          1508            10          1627            11
# 6551772          1245             7          1400             9
#
#          CRS_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP  DEP_DELAY_GROUP
# 0                     114       425               2               -1
# 1                      86       425               2               -1
# 2                     112       563               3               -1
# 3                      72       232               1               -1
# 4                     130       743               3               -1
# ...                   ...       ...             ...              ...
# 6551768               128       479               2               -1
# 6551769               143       900               4               -1
# 6551770               149       900               4               -1
# 6551771                79       196               1               -1
# 6551772                75       196               1               -1
#
# [6551773 rows x 23 columns]

# %%
training_df.dtypes
# Out:
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# OP_CARRIER_AIRLINE_ID    int64
# TAIL_NUM                 int64
# OP_CARRIER_FL_NUM        int64
# ORIGIN_AIRPORT_ID        int64
# ORIGIN_CITY_MARKET_ID    int64
# ORIGIN_STATE_FIPS        int64
# ORIGIN_WAC               int64
# DEST_AIRPORT_ID          int64
# DEST_CITY_MARKET_ID      int64
# DEST_STATE_FIPS          int64
# DEST_WAC                 int64
# CRS_DEP_TIME             int64
# DEP_TIME_BLK             int64
# CRS_ARR_TIME             int64
# ARR_TIME_BLK             int64
# CRS_ELAPSED_TIME         int64
# DISTANCE                 int64
# DISTANCE_GROUP           int64
# DEP_DELAY_GROUP          int64
# dtype: object

# %%
categorical_columns = [
    "OP_CARRIER_AIRLINE_ID",
    "TAIL_NUM",
    "OP_CARRIER_FL_NUM",

    "ORIGIN_AIRPORT_ID",
    "ORIGIN_CITY_MARKET_ID",
    "ORIGIN_STATE_FIPS",
    "ORIGIN_WAC",
    "DEST_AIRPORT_ID",
    "DEST_CITY_MARKET_ID",
    "DEST_STATE_FIPS",
    "DEST_WAC",
]

for column in categorical_columns:
    training_df[column] = training_df[column].astype('category')

# %%
training_df.dtypes
# Out:
# QUARTER                     int64
# MONTH                       int64
# DAY_OF_MONTH                int64
# DAY_OF_WEEK                 int64
# OP_CARRIER_AIRLINE_ID    category
# TAIL_NUM                 category
# OP_CARRIER_FL_NUM        category
# ORIGIN_AIRPORT_ID        category
# ORIGIN_CITY_MARKET_ID    category
# ORIGIN_STATE_FIPS        category
# ORIGIN_WAC               category
# DEST_AIRPORT_ID          category
# DEST_CITY_MARKET_ID      category
# DEST_STATE_FIPS          category
# DEST_WAC                 category
# CRS_DEP_TIME                int64
# DEP_TIME_BLK                int64
# CRS_ARR_TIME                int64
# ARR_TIME_BLK                int64
# CRS_ELAPSED_TIME            int64
# DISTANCE                    int64
# DISTANCE_GROUP              int64
# DEP_DELAY_GROUP             int64
# dtype: object

# %% [markdown]
# ## Defining functions for model evaluation

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def evaluate_model(data_df, features_columns, target_column):
    features = data_df[features_columns]
    target = data_df[target_column]
    X_array = features.values
    y_array = target.values
    
    rmse_scores = []
    mae_scores = []
    
    kf = KFold(n_splits=2, shuffle=True, random_state=123)
    
    for train_index, test_index in kf.split(X_array):
        model = xgb.XGBRegressor(
            enable_categorical=True,
            objective='reg:squarederror', 
            eval_metric='rmse',
            random_state=123
        )
        
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = target.iloc[train_index], target.iloc[test_index]
        
        model.fit(X_train, y_train)
        
        y_pred = model.predict(X_test)
        
        rmse_scores.append(rmse(y_test, y_pred))
        mae_scores.append(mean_absolute_error(y_test, y_pred))
        
    return np.mean(rmse_scores), np.mean(mae_scores)

# %% [markdown]
# ## Training and Evaluation using 2-fold Cross Validation

# %% [markdown]
# ## Try different minute intervall in hours

# %%
def generate_categories(intervall_in_minutes: int) -> dict:
    intervalls = {}

    intervalls[-2] = {
        "min": float('-inf'),
        "max": -15
    }

    intervalls[-1] = {
        "min": -15,
        "max": 0
    }

    for start in range(0, 181, intervall_in_minutes):
        end = start + intervall_in_minutes
        category = int(start/intervall_in_minutes)
        intervalls[category] = {
            "min": start,
            "max": end if start < 180 else float('+Inf')
        }

    return intervalls

# %%
# Function to categorize DEP_DELAY values
def categorize_minutes(minutes_value, intervalls):
    for category, category_limits in intervalls.items():
        if minutes_value >= category_limits["min"] and minutes_value < category_limits["max"]:
            return category
    return category

# %%
intervalls_array = []
intervall_rmse_scores = []
intervall_mae_scores = []
expected_errors_rmse_based = []
expected_errors_mae_based = []

for i in range(1, 61):
    if 60 % i == 0:
        intervall_in_minutes = int(60/i)
        intervalls_array.append(intervall_in_minutes)
        print(f"{intervall_in_minutes = }")
        intervalls = generate_categories(intervall_in_minutes=intervall_in_minutes)
        target_new = f'DEP_DELAY_GROUP_NEW_{intervall_in_minutes}'
        dataset_df[target_new] = dataset_df['DEP_DELAY'].apply(lambda x: categorize_minutes(x, intervalls))
        training_df_new = dataset_df[features+ [target_new]]
        rmse_score, mae_score = evaluate_model(
            data_df=training_df_new, 
            features_columns=features, 
            target_column=target_new
        )
        expected_error_rmse_based = rmse_score*intervall_in_minutes
        expected_error_mae_based = mae_score*intervall_in_minutes
        
        intervall_rmse_scores.append(rmse_score)
        intervall_mae_scores.append(mae_score)
        expected_errors_rmse_based.append(expected_error_rmse_based)
        expected_errors_mae_based.append(expected_error_mae_based)
        
        print("Evaluation: Root Mean Squared Error:", rmse_score)
        print("Evaluation: Mean Absolute Error:", mae_score)
        print("Evaluation: Expected Error (RMSE Based):", expected_error_rmse_based)
        print("Evaluation: Expected Error (MAE Based):", expected_error_mae_based)
        print("----------------------------------------------------------")
# Out:
# intervall_in_minutes = 60
# Evaluation: Root Mean Squared Error: 0.7110691075676541
# Evaluation: Mean Absolute Error: 0.5317671589915098
# Evaluation: Expected Error (RMSE Based): 42.66414645405924
# Evaluation: Expected Error (MAE Based): 31.90602953949059
# ----------------------------------------------------------
# intervall_in_minutes = 30
# Evaluation: Root Mean Squared Error: 1.1729194760215647
# Evaluation: Mean Absolute Error: 0.7569319338043357
# Evaluation: Expected Error (RMSE Based): 35.18758428064694
# Evaluation: Expected Error (MAE Based): 22.70795801413007
# ----------------------------------------------------------
# intervall_in_minutes = 20
# Evaluation: Root Mean Squared Error: 1.6644004124474585
# Evaluation: Mean Absolute Error: 1.0156142685980671
# Evaluation: Expected Error (RMSE Based): 33.28800824894917
# Evaluation: Expected Error (MAE Based): 20.312285371961345
# ----------------------------------------------------------
# intervall_in_minutes = 15
# Evaluation: Root Mean Squared Error: 2.165487377248664
# Evaluation: Mean Absolute Error: 1.2891948850957196
# Evaluation: Expected Error (RMSE Based): 32.48231065872996
# Evaluation: Expected Error (MAE Based): 19.337923276435795
# ----------------------------------------------------------
# intervall_in_minutes = 12
# Evaluation: Root Mean Squared Error: 2.667214878422806
# Evaluation: Mean Absolute Error: 1.5676227140495815
# Evaluation: Expected Error (RMSE Based): 32.00657854107367
# Evaluation: Expected Error (MAE Based): 18.81147256859498
# ----------------------------------------------------------
# intervall_in_minutes = 10
# Evaluation: Root Mean Squared Error: 3.171158959337835
# Evaluation: Mean Absolute Error: 1.850781425530677
# Evaluation: Expected Error (RMSE Based): 31.71158959337835
# Evaluation: Expected Error (MAE Based): 18.50781425530677
# ----------------------------------------------------------
# intervall_in_minutes = 6
# Evaluation: Root Mean Squared Error: 5.1900225586584385
# Evaluation: Mean Absolute Error: 2.992745215098807
# Evaluation: Expected Error (RMSE Based): 31.140135351950633
# Evaluation: Expected Error (MAE Based): 17.95647129059284
# ----------------------------------------------------------
# intervall_in_minutes = 5
# Evaluation: Root Mean Squared Error: 6.201751013938326
# Evaluation: Mean Absolute Error: 3.5669036492311603
# Evaluation: Expected Error (RMSE Based): 31.00875506969163
# Evaluation: Expected Error (MAE Based): 17.834518246155803
# ----------------------------------------------------------
# intervall_in_minutes = 4
# Evaluation: Root Mean Squared Error: 7.710973435813142
# Evaluation: Mean Absolute Error: 4.423502507558157
# Evaluation: Expected Error (RMSE Based): 30.84389374325257
# Evaluation: Expected Error (MAE Based): 17.69401003023263
# ----------------------------------------------------------
# intervall_in_minutes = 3
# Evaluation: Root Mean Squared Error: 10.23784880784428
# Evaluation: Mean Absolute Error: 5.85856353692091
# Evaluation: Expected Error (RMSE Based): 30.71354642353284
# Evaluation: Expected Error (MAE Based): 17.575690610762727
# ----------------------------------------------------------
# intervall_in_minutes = 2
# Evaluation: Root Mean Squared Error: 15.292491303553012
# Evaluation: Mean Absolute Error: 8.732141479600426
# Evaluation: Expected Error (RMSE Based): 30.584982607106024
# Evaluation: Expected Error (MAE Based): 17.46428295920085
# ----------------------------------------------------------
# intervall_in_minutes = 1
# Evaluation: Root Mean Squared Error: 30.477562073789358
# Evaluation: Mean Absolute Error: 17.365220606137925
# Evaluation: Expected Error (RMSE Based): 30.477562073789358
# Evaluation: Expected Error (MAE Based): 17.365220606137925
# ----------------------------------------------------------

# %% [markdown]
# ## Plot all results

# %%
# Create a figure and set up subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot scores
ax1.plot(intervalls_array, intervall_rmse_scores, label='RMSE Scores')
ax1.plot(intervalls_array, intervall_mae_scores, label='MAE Scores')
ax1.set_title('RMSE/MAE Scores vs. Chosen Minute Intervalls')
ax1.set_xlabel('Intervalls')
ax1.set_ylabel('Scores')
ax1.set_xticks(intervalls_array)  # Limit x-axis ticks to those in intervalls
ax1.grid() # Turn on grid 
ax1.legend()

# Plot expected errors based on scores
ax2.plot(intervalls_array, expected_errors_rmse_based, label='Expected Error Based on RMSE')
ax2.plot(intervalls_array, expected_errors_mae_based, label='Expected Error Based on MAE')
ax2.set_title('Expected Errors Based on RMSE/MAE Scores vs. Chosen Minute Intervalls')
ax2.set_xlabel('Intervalls')
ax2.set_ylabel('Expected Errors in minutes')
ax2.set_xticks(intervalls_array)  # Limit x-axis ticks to those in intervalls
ax2.grid() # Turn on grid 
ax2.legend()

# Display the plots
plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

# %% [markdown]
# ## Train model based on 1 minute intervall
# - from 0 to 179 minutes: One category per minute
# - from 180 and over: One dedicated category for any delay larger than 3 hours
# - from -1 to -15: One dedicated category for early departure larger than 15 minutes
# - from -16 and lower: One dedicated category for any early departure smaller than 15 minutes.

# %%
intervall_in_minutes = 1
intervalls = generate_categories(intervall_in_minutes=intervall_in_minutes)
target_new = 'DEP_DELAY_GROUP_NEW_1'
dataset_df[target_new] = dataset_df['DEP_DELAY'].apply(lambda x: categorize_minutes(x, intervalls))
training_df_new = dataset_df[features+ [target_new]]

# %%
model = xgb.XGBRegressor(
    enable_categorical=True,
    objective='reg:squarederror', 
    eval_metric='rmse',
    random_state=123
)
        
model.fit(training_df_new[features], training_df_new[target_new])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=123, ...)

# %%
# Load the 2023 testing datset
# Use os.path.join to create the full file path
testing_dataset_filename = "encoded_evaluation_dataset_2023.csv"
file_path = os.path.join(data_dir, testing_dataset_filename)

# Read the CSV file into a DataFrame
dataset_2023_df = pd.read_csv(file_path)
testing_df = dataset_2023_df[features+ ['DEP_DELAY']].copy()

# %%
intervalls = generate_categories(intervall_in_minutes=1)
target_new = 'DEP_DELAY_GROUP_NEW_1'
testing_df[target_new] = testing_df['DEP_DELAY'].apply(lambda x: categorize_minutes(x, intervalls))

# %%
# Display the DataFrame
display(testing_df)
# Out:
#          QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  \
# 0              1      1             1            7                  20363
# 1              1      1             1            7                  20363
# 2              1      1             1            7                  20363
# 3              1      1             1            7                  20363
# 4              1      1             1            7                  20363
# ...          ...    ...           ...          ...                    ...
# 6763361        4     12            31            7                  20452
# 6763362        4     12            31            7                  20452
# 6763363        4     12            31            7                  20452
# 6763364        4     12            31            7                  20452
# 6763365        4     12            31            7                  20452
#
#          TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0             319               5244              13930
# 1             319               5317              12478
# 2             319               5397              12478
# 3             332               5076              10397
# 4             332               5076              14783
# ...           ...                ...                ...
# 6763361      5247               5680              10721
# 6763362      5247               5701              14122
# 6763363      6245               3428              10431
# 6763364      6245               3517              11193
# 6763365      6245               3678              13930
#
#          ORIGIN_CITY_MARKET_ID  ORIGIN_STATE_FIPS  ORIGIN_WAC  \
# 0                        30977                 17          41
# 1                        31703                 36          22
# 2                        31703                 36          22
# 3                        30397                 13          34
# 4                        34783                 29          64
# ...                        ...                ...         ...
# 6763361                  30721                 25          13
# 6763362                  30198                 42          23
# 6763363                  30431                 37          36
# 6763364                  33105                 21          52
# 6763365                  30977                 17          41
#
#          DEST_AIRPORT_ID  DEST_CITY_MARKET_ID  DEST_STATE_FIPS  DEST_WAC  \
# 0                  12478                31703               36        22
# 1                  13930                30977               17        41
# 2                  10581                30581               23        12
# 3                  14783                34783               29        64
# 4                  10397                30397               13        34
# ...                  ...                  ...              ...       ...
# 6763361            11066                31066               39        44
# 6763362            10721                30721               25        13
# 6763363            13930                30977               17        41
# 6763364            13930                30977               17        41
# 6763365            10431                30431               37        36
#
#          CRS_DEP_TIME  DEP_TIME_BLK  CRS_ARR_TIME  ARR_TIME_BLK  \
# 0                1520            10          1841            13
# 1                 945             4          1144             6
# 2                2100            16          2236            17
# 3                1130             6          1225             7
# 4                1400             9          1637            11
# ...               ...           ...           ...           ...
# 6763361          1315             8          1538            10
# 6763362          1038             5          1222             7
# 6763363          1515            10          1627            11
# 6763364           900             4           946             4
# 6763365          1105             6          1357             8
#
#          CRS_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP  DEP_DELAY  \
# 0                     141       740               3          4
# 1                     179       740               3         -4
# 2                      96       382               2         -4
# 3                     115       563               3         -5
# 4                      97       563               3         -6
# ...                   ...       ...             ...        ...
# 6763361               143       640               3         -5
# 6763362               104       496               2         -7
# 6763363               132       536               3         -7
# 6763364               106       264               2         -7
# 6763365               112       536               3         -7
#
#          DEP_DELAY_GROUP_NEW_1
# 0                            4
# 1                           -1
# 2                           -1
# 3                           -1
# 4                           -1
# ...                        ...
# 6763361                     -1
# 6763362                     -1
# 6763363                     -1
# 6763364                     -1
# 6763365                     -1
#
# [6763366 rows x 24 columns]

# %%
y_pred = model.predict(testing_df[features].values)

# %%
y_test = testing_df['DEP_DELAY_GROUP_NEW_1'].values

print("Using DEP_DELAY_GROUP_NEW_1 as target in a regressor trained with DEP_DELAY_GROUP_NEW_1")
testing_rmse_score = rmse(y_test, y_pred)
print(f"Evaluation: Root Mean Squared Error: {testing_rmse_score}")
testing_mae_score = mean_absolute_error(y_test, y_pred)
print(f"Evaluation: Mean Absolute Error: {testing_mae_score}")
# Out:
# Using DEP_DELAY_GROUP_NEW_1 as target in a regressor trained with DEP_DELAY_GROUP_NEW_1
# Evaluation: Root Mean Squared Error: 31.765214346565326
# Evaluation: Mean Absolute Error: 18.410472240274004

# %% [markdown]
# ## Train a XGBoost Regressor using DEP_DELAY as target

# %%
target = 'DEP_DELAY'

model = xgb.XGBRegressor(
    enable_categorical=True,
    objective='reg:squarederror', 
    eval_metric='rmse',
    random_state=123
)
        
model.fit(dataset_df[features], dataset_df[target])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=123, ...)

# %%
y_pred = model.predict(testing_df[features].values)

# %%
y_test = testing_df['DEP_DELAY'].values

print("Using DEP_DELAY as target in a regressor trained with DEP_DELAY")
testing_rmse_score = rmse(y_test, y_pred)
print(f"Evaluation: Root Mean Squared Error: {testing_rmse_score}")
testing_mae_score = mean_absolute_error(y_test, y_pred)
print(f"Evaluation: Mean Absolute Error: {testing_mae_score}")
# Out:
# Using DEP_DELAY as target in a regressor trained with DEP_DELAY
# Evaluation: Root Mean Squared Error: 55.03864371797086
# Evaluation: Mean Absolute Error: 22.981131763890577
